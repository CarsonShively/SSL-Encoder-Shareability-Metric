# %% [markdown]
# # Sample Data EDA

# %%
import pandas as pd
from pathlib import Path

# %%
# requires current workking directory /SSL-Encoder-Shareability-Metric/
df = pd.read_csv(Path().cwd().resolve().parent / "data/sample_data.csv")

# %% [markdown]
# ## Sample Data Overview

# %%
# drop station and No
df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %% [markdown]
# ## Categorical Unique Count

# %%
# start with continous only so drop in beginning
df["wd"].nunique()
# Out:
# 16

# %% [markdown]
# ## Check nan value counts relative to total rows

# %%
# approximately 5% == drop
print(len(df))
df.isna().sum()
# Out:
# 35064
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       925
# PM10        718
# SO2         935
# NO2        1023
# CO         1776
# O3         1719
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %% [markdown]
# ## Duplicates within a timestep

# %%
# no duplicates within a time step, preserving t and t+1 pairs
df["datetime"] = pd.to_datetime(df[["year", "month", "day", "hour"]])
print(df["datetime"].duplicated().sum())
# Out:
# 0
